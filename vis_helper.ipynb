# %%
import os
import csv
import numpy as np
import cv2
import sklearn
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Flatten,Dense,Lambda,Conv2D,MaxPool2D,Dropout,Cropping2D
from keras.optimizers import Adam
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
samples = []
with open('./data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        samples.append(line)

# %%
samples[5]
# Out:
# ['C:\\sim\\IMG\\center_2017_10_08_18_23_15_441.jpg',
#  'C:\\sim\\IMG\\left_2017_10_08_18_23_15_441.jpg',
#  'C:\\sim\\IMG\\right_2017_10_08_18_23_15_441.jpg',
#  '-0.45',
#  '1',
#  '0',
#  '24.49354']

# %%
images = []
name = './data/IMG/'+samples[5][0].split('\\')[3]
name_left = './data/IMG/'+samples[5][1].split('\\')[3]
name_right = './data/IMG/'+samples[5][2].split('\\')[3]
center_image = mpimg.imread(name)
left_image = mpimg.imread(name_left)
right_image = mpimg.imread(name_right)
center_image_flip = cv2.flip(center_image,1)
left_image_flip = cv2.flip(left_image,1)
right_image_flip = cv2.flip(right_image,1)
images.append(center_image)
images.append(left_image)
images.append(right_image)
images.append(center_image_flip)
images.append(left_image_flip)
images.append(right_image_flip)

import matplotlib.pyplot as plt
    
fig_size = plt.rcParams["figure.figsize"]
fig_size[1] = 5
fig_size[0] = 17
plt.rcParams["figure.figsize"] = fig_size
    
    
    
maxi = len(images)
for i in range(maxi):
    plt.subplot(1,maxi,i+1)
    plt.imshow(images[i])
plt.show()

# %%
import matplotlib.pyplot as plt
#sa = np.array(samples)
#labels = sa[:,3:4]
#labels.dtype = np.float32

labels = []
labels = [sublist[3:4] for sublist in samples]
#labels
labels2 = [float(item[0]) for item in labels]
labels2
prep_labels = {}
y_pos = np.arange(len(labels2))
plt.bar(y_pos,labels2)

plt.show()

# %%
import pydot 
pydot.Dot.create(pydot.Dot())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.6/site-packages/pydot.py in create(self, prog, format)
#    1877                 shell=False,
# -> 1878                 stderr=subprocess.PIPE, stdout=subprocess.PIPE)
#    1879         except OSError as e:
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# ...
